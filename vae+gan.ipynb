# %%
import os
import numpy as np
import librosa
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             confusion_matrix, roc_auc_score, average_precision_score)

# ===== Environment & Threading Settings to Avoid MKL Errors =====
os.environ["TF_ENABLE_MKL_NATIVE_FORMAT"] = "0"      # Disable MKL native format
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"               # Suppress info messages
tf.config.threading.set_intra_op_parallelism_threads(1)
tf.config.threading.set_inter_op_parallelism_threads(1)

# ===== Enable eager execution and reset graph =====
tf.keras.backend.clear_session()
tf.config.run_functions_eagerly(True)
tf.compat.v1.reset_default_graph()
tf.data.experimental.enable_debug_mode()  # Suppress tf.data eager warnings

# %%
def load_audio_files(directory, sr=22050, duration=5):
    """Loads audio files from a directory."""
    audio_data = []
    for folder in os.listdir(directory):
        folder_path = os.path.join(directory, folder)
        if not os.path.isdir(folder_path):
            continue        
        for file in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file)
            if not file_path.endswith(('.wav', '.mp3')):
                continue            
            try:
                signal, _ = librosa.load(file_path, sr=sr, duration=duration)
                audio_data.append(signal)
            except Exception as e:
                print(f"Error loading {file_path}: {e}")
    return np.array(audio_data, dtype=object)

# %%
def augment_audio(audio, sr=22050):
    """Apply simple pitch shifting and noise injection to augment audio."""
    n_steps = np.random.uniform(-2, 2)
    audio_shifted = librosa.effects.pitch_shift(y=audio, sr=sr, n_steps=n_steps)
    noise = 0.005 * np.random.randn(len(audio_shifted))
    return audio_shifted + noise

# %%
def extract_spectrograms(audio_data, sr=22050, n_fft=2048, hop_length=512, n_mels=128, max_time_frames=128):
    """
    Computes mel-spectrograms (in decibels) and normalizes them to [0,1].
    Returns images of shape (n_mels, max_time_frames).
    """
    specs = []
    for sample in audio_data:
        if len(sample) == 0:
            continue
        mel_spec = librosa.feature.melspectrogram(y=sample, sr=sr, n_fft=n_fft,
                                                  hop_length=hop_length, n_mels=n_mels)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
        # Add epsilon to denominator to avoid division by zero.
        mel_norm = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min() + 1e-9)
        if mel_norm.shape[1] < max_time_frames:
            pad_width = max_time_frames - mel_norm.shape[1]
            mel_norm = np.pad(mel_norm, ((0,0),(0,pad_width)), mode='constant')
        else:
            mel_norm = mel_norm[:, :max_time_frames]
        specs.append(mel_norm)
    return np.array(specs)

# %%
def prepare_spectrogram_images(specs):
    """
    Expands spectrograms to have a channel dimension.
    Input shape: (num_samples, n_mels, time_frames)
    Output shape: (num_samples, n_mels, time_frames, 1)
    """
    return np.expand_dims(specs, axis=-1)

# %%
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

def build_encoder(latent_dim, input_shape=(128,128,1)):
    inputs = keras.Input(shape=input_shape)
    x = layers.Conv2D(32, 3, strides=2, padding='same', activation='relu')(inputs)  # 64x64x32
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, 3, strides=2, padding='same', activation='relu')(x)       # 32x32x64
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, 3, strides=2, padding='same', activation='relu')(x)      # 16x16x128
    x = layers.BatchNormalization()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(256, activation='relu')(x)
    z_mean = layers.Dense(latent_dim, name='z_mean')(x)
    z_log_var = layers.Dense(latent_dim, name='z_log_var')(x)
    z = Sampling()([z_mean, z_log_var])
    return keras.Model(inputs, [z_mean, z_log_var, z], name='encoder')

def build_decoder(latent_dim, output_shape=(128,128,1)):
    latent_inputs = keras.Input(shape=(latent_dim,))
    x = layers.Dense(16*16*128, activation='relu')(latent_inputs)
    x = layers.Reshape((16,16,128))(x)
    x = layers.Conv2DTranspose(128, 3, strides=2, padding='same', activation='relu')(x)  # 32x32x128
    x = layers.BatchNormalization()(x)
    x = layers.Conv2DTranspose(64, 3, strides=2, padding='same', activation='relu')(x)   # 64x64x64
    x = layers.BatchNormalization()(x)
    x = layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu')(x)   # 128x128x32
    x = layers.BatchNormalization()(x)
    outputs = layers.Conv2DTranspose(1, 3, padding='same', activation='sigmoid')(x)       # 128x128x1
    return keras.Model(latent_inputs, outputs, name='decoder')

def build_discriminator(input_shape=(128,128,1)):
    inputs = keras.Input(shape=input_shape)
    x = layers.Conv2D(32, 3, strides=2, padding='same', activation='relu')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(64, activation='relu')(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    return keras.Model(inputs, outputs, name='discriminator')

# %%
class VAE_GAN(keras.Model):
    def __init__(self, encoder, decoder, discriminator, lambda_adv=0.5, **kwargs):
        super(VAE_GAN, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.discriminator = discriminator
        self.lambda_adv = lambda_adv

    def call(self, inputs, training=False):
        z_mean, z_log_var, z = self.encoder(inputs, training=training)
        reconstructed = self.decoder(z, training=training)
        return reconstructed

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape_gen, tf.GradientTape() as tape_disc:
            z_mean, z_log_var, z = self.encoder(data, training=True)
            # Clip z_log_var to avoid numerical issues in exp
            z_log_var = tf.clip_by_value(z_log_var, -10.0, 10.0)
            reconstructed = self.decoder(z, training=True)
            reconstruction_loss = tf.reduce_mean(tf.keras.losses.mse(data, reconstructed))
            kl_loss = -0.5 * tf.reduce_mean(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
           
            disc_pred_fake = self.discriminator(reconstructed, training=True)
            # Clip discriminator predictions to avoid log(0) issues in binary crossentropy
            disc_pred_fake = tf.clip_by_value(disc_pred_fake, 1e-7, 1.0 - 1e-7)
            valid_labels = tf.ones_like(disc_pred_fake)
            adv_loss = tf.keras.losses.binary_crossentropy(valid_labels, disc_pred_fake)
            adv_loss = tf.reduce_mean(adv_loss)
            gen_loss = reconstruction_loss + kl_loss + self.lambda_adv * adv_loss

            disc_pred_real = self.discriminator(data, training=True)
            disc_pred_real = tf.clip_by_value(disc_pred_real, 1e-7, 1.0 - 1e-7)
            real_loss = tf.keras.losses.binary_crossentropy(tf.ones_like(disc_pred_real), disc_pred_real)
            fake_loss = tf.keras.losses.binary_crossentropy(tf.zeros_like(disc_pred_fake), disc_pred_fake)
            disc_loss = tf.reduce_mean(real_loss) + tf.reduce_mean(fake_loss)
        # Compute gradients
        grads_gen = tape_gen.gradient(gen_loss, self.encoder.trainable_variables + self.decoder.trainable_variables)
        grads_disc = tape_disc.gradient(disc_loss, self.discriminator.trainable_variables)
        # Apply global gradient clipping to prevent explosion
        grads_gen, _ = tf.clip_by_global_norm(grads_gen, 1.0)
        grads_disc, _ = tf.clip_by_global_norm(grads_disc, 1.0)
        # Apply gradients
        self.gen_optimizer.apply_gradients(zip(grads_gen, self.encoder.trainable_variables + self.decoder.trainable_variables))
        self.disc_optimizer.apply_gradients(zip(grads_disc, self.discriminator.trainable_variables))
        return {"gen_loss": gen_loss,
                "reconstruction_loss": reconstruction_loss,
                "kl_loss": kl_loss,
                "adv_loss": adv_loss,
                "disc_loss": disc_loss}

    def test_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        z_mean, z_log_var, z = self.encoder(data, training=False)
        z_log_var = tf.clip_by_value(z_log_var, -10.0, 10.0)
        reconstructed = self.decoder(z, training=False)
        reconstruction_loss = tf.reduce_mean(tf.keras.losses.mse(data, reconstructed))
        kl_loss = -0.5 * tf.reduce_mean(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        disc_pred_fake = self.discriminator(reconstructed, training=False)
        disc_pred_fake = tf.clip_by_value(disc_pred_fake, 1e-7, 1.0 - 1e-7)
        valid_labels = tf.ones_like(disc_pred_fake)
        adv_loss = tf.keras.losses.binary_crossentropy(valid_labels, disc_pred_fake)
        adv_loss = tf.reduce_mean(adv_loss)
        gen_loss = reconstruction_loss + kl_loss + self.lambda_adv * adv_loss
        return {"gen_loss": gen_loss,
                "reconstruction_loss": reconstruction_loss,
                "kl_loss": kl_loss,
                "adv_loss": adv_loss}

# %%
def generate_synthetic_anomalies(images, noise_factor=2.0):
    """
    Create synthetic anomalies by adding heavy Gaussian noise.
    """
    anomalies = images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=images.shape)
    return np.clip(anomalies, 0, 1)

def compute_threshold(losses, k=1.5):
    return np.mean(losses) + k * np.std(losses)

def compute_reconstruction_loss(original, reconstructed):
    return np.mean(np.square(original - reconstructed), axis=(1,2,3))

# %%
# Paths (DO NOT CHANGE)
dataset_path = "/Users/aiswaryamariamjacob/major-project/archive (1)/Raw Audio"
test_path = "/Users/aiswaryamariamjacob/major-project/Test Data"

# 1. Load audio files
audio_samples = load_audio_files(dataset_path)
test_samples = load_audio_files(test_path)

# 2. Augment audio for training
augmented_audio = [augment_audio(a) for a in audio_samples]
audio_train_all = list(audio_samples) + augmented_audio

# 3. Extract mel-spectrograms (in decibels) from audio
specs_train = extract_spectrograms(audio_train_all, sr=22050, n_fft=2048, hop_length=512, n_mels=128, max_time_frames=128)
specs_test = extract_spectrograms(test_samples, sr=22050, n_fft=2048, hop_length=512, n_mels=128, max_time_frames=128)

# 4. Expand dims to have channel dimension
X_all = prepare_spectrogram_images(specs_train)
X_test = prepare_spectrogram_images(specs_test)

# 5. Train-Val split (unsupervised; all assumed normal)
X_train, X_val = train_test_split(X_all, test_size=0.2, random_state=42)

print("Final X_train shape:", X_train.shape)
print("Final X_val shape:", X_val.shape)
print("Final X_test shape:", X_test.shape)

# 6. Build VAE + GAN components (input shape: (128,128,1), latent_dim=32)
latent_dim = 32
encoder = build_encoder(latent_dim, input_shape=(128,128,1))
decoder = build_decoder(latent_dim, output_shape=(128,128,1))
discriminator = build_discriminator(input_shape=(128,128,1))

# 7. Initialize VAE + GAN model
vae_gan = VAE_GAN(encoder, decoder, discriminator, lambda_adv=0.5)

# 8. Set up optimizers with a lower learning rate
vae_gan.gen_optimizer = keras.optimizers.Adam(learning_rate=1e-4)
vae_gan.disc_optimizer = keras.optimizers.Adam(learning_rate=1e-4)

# 8.5 Compile the model (dummy compile; custom train_step is used)
vae_gan.compile(optimizer=vae_gan.gen_optimizer)

# 9. Train the VAE + GAN
vae_gan.fit(X_train, epochs=50, batch_size=32, validation_data=(X_val,))
# Out:
# Final X_train shape: (2684, 128, 128, 1)
# Final X_val shape: (672, 128, 128, 1)
# Final X_test shape: (262, 128, 128, 1)
# Epoch 1/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 7.0704 - disc_loss: 0.1573 - gen_loss: 5.3012 - kl_loss: 1.5666 - reconstruction_loss: 0.1993 - val_adv_loss: 0.1644 - val_gen_loss: 0.2983 - val_kl_loss: 0.1116 - val_reconstruction_loss: 0.1045
# Epoch 2/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 10.9838 - disc_loss: 0.1116 - gen_loss: 8.0674 - kl_loss: 2.3575 - reconstruction_loss: 0.2180 - val_adv_loss: 8.5617e-04 - val_gen_loss: 0.2953 - val_kl_loss: 0.2167 - val_reconstruction_loss: 0.0782
# Epoch 3/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 13.3878 - disc_loss: 0.1483 - gen_loss: 8.4509 - kl_loss: 1.5623 - reconstruction_loss: 0.1947 - val_adv_loss: 16.1181 - val_gen_loss: 8.7952 - val_kl_loss: 0.6621 - val_reconstruction_loss: 0.0741
# Epoch 4/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 15.6006 - disc_loss: 0.0799 - gen_loss: 8.1590 - kl_loss: 0.1853 - reconstruction_loss: 0.1734 - val_adv_loss: 16.1181 - val_gen_loss: 8.1360 - val_kl_loss: 0.0076 - val_reconstruction_loss: 0.0694
# Epoch 5/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 182s 2s/step - adv_loss: 15.9929 - disc_loss: 0.0141 - gen_loss: 8.1620 - kl_loss: 0.0130 - reconstruction_loss: 0.1526 - val_adv_loss: 16.1181 - val_gen_loss: 8.1281 - val_kl_loss: 0.0033 - val_reconstruction_loss: 0.0658
# Epoch 6/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 181s 2s/step - adv_loss: 16.1181 - disc_loss: 0.0060 - gen_loss: 8.2069 - kl_loss: 0.0367 - reconstruction_loss: 0.1112 - val_adv_loss: 15.8327 - val_gen_loss: 7.9863 - val_kl_loss: 0.0012 - val_reconstruction_loss: 0.0687
# Epoch 7/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 181s 2s/step - adv_loss: 15.5145 - disc_loss: 0.0073 - gen_loss: 7.8698 - kl_loss: 0.0257 - reconstruction_loss: 0.0868 - val_adv_loss: 7.9189 - val_gen_loss: 4.0276 - val_kl_loss: 1.9852e-04 - val_reconstruction_loss: 0.0680
# Epoch 8/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 14.8110 - disc_loss: 0.0104 - gen_loss: 7.8402 - kl_loss: 0.2939 - reconstruction_loss: 0.1408 - val_adv_loss: 16.1181 - val_gen_loss: 8.1496 - val_kl_loss: 5.4217e-04 - val_reconstruction_loss: 0.0900
# Epoch 9/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 181s 2s/step - adv_loss: 16.1129 - disc_loss: 1.3227e-04 - gen_loss: 8.1701 - kl_loss: 0.0146 - reconstruction_loss: 0.0990 - val_adv_loss: 16.1008 - val_gen_loss: 8.1234 - val_kl_loss: 7.2996e-05 - val_reconstruction_loss: 0.0729
# Epoch 10/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 16.1126 - disc_loss: 1.3862e-04 - gen_loss: 8.1947 - kl_loss: 0.0615 - reconstruction_loss: 0.0769 - val_adv_loss: 12.1393 - val_gen_loss: 6.1365 - val_kl_loss: 7.0302e-05 - val_reconstruction_loss: 0.0668
# Epoch 11/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 187s 2s/step - adv_loss: 16.1181 - disc_loss: 2.1112e-05 - gen_loss: 8.1448 - kl_loss: 0.0173 - reconstruction_loss: 0.0685 - val_adv_loss: 3.7968 - val_gen_loss: 1.9653 - val_kl_loss: 5.7689e-05 - val_reconstruction_loss: 0.0668
# Epoch 12/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 16.1181 - disc_loss: 2.3914e-07 - gen_loss: 8.1312 - kl_loss: 0.0090 - reconstruction_loss: 0.0632 - val_adv_loss: 0.2492 - val_gen_loss: 0.1867 - val_kl_loss: 1.2207e-04 - val_reconstruction_loss: 0.0620
# Epoch 13/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 181s 2s/step - adv_loss: 15.9834 - disc_loss: 0.0012 - gen_loss: 8.0580 - kl_loss: 0.0051 - reconstruction_loss: 0.0612 - val_adv_loss: 0.0011 - val_gen_loss: 0.0740 - val_kl_loss: 5.8002e-05 - val_reconstruction_loss: 0.0733
# Epoch 14/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 188s 2s/step - adv_loss: 16.1174 - disc_loss: 2.9183e-05 - gen_loss: 8.1287 - kl_loss: 0.0063 - reconstruction_loss: 0.0637 - val_adv_loss: 1.5611 - val_gen_loss: 0.8439 - val_kl_loss: 3.6531e-05 - val_reconstruction_loss: 0.0633
# Epoch 15/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 188s 2s/step - adv_loss: 16.1181 - disc_loss: 4.5835e-06 - gen_loss: 8.1288 - kl_loss: 0.0114 - reconstruction_loss: 0.0583 - val_adv_loss: 1.3963 - val_gen_loss: 0.7531 - val_kl_loss: 1.6763e-05 - val_reconstruction_loss: 0.0550
# Epoch 16/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 183s 2s/step - adv_loss: 16.1181 - disc_loss: 1.8699e-06 - gen_loss: 8.1204 - kl_loss: 0.0042 - reconstruction_loss: 0.0571 - val_adv_loss: 1.8768 - val_gen_loss: 0.9959 - val_kl_loss: 1.6352e-05 - val_reconstruction_loss: 0.0575
# Epoch 17/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 2.6943e-07 - gen_loss: 8.1168 - kl_loss: 9.9676e-04 - reconstruction_loss: 0.0567 - val_adv_loss: 1.2877 - val_gen_loss: 0.6981 - val_kl_loss: 9.3710e-06 - val_reconstruction_loss: 0.0542
# Epoch 18/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 4.9331e-07 - gen_loss: 8.1154 - kl_loss: 5.4069e-05 - reconstruction_loss: 0.0563 - val_adv_loss: 1.7707 - val_gen_loss: 0.9381 - val_kl_loss: 6.8564e-06 - val_reconstruction_loss: 0.0527
# Epoch 19/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 16.1181 - disc_loss: 2.5832e-07 - gen_loss: 8.1147 - kl_loss: 6.1717e-06 - reconstruction_loss: 0.0557 - val_adv_loss: 1.5075 - val_gen_loss: 0.8073 - val_kl_loss: 4.9789e-06 - val_reconstruction_loss: 0.0535
# Epoch 20/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 2.6704e-07 - gen_loss: 8.1145 - kl_loss: 5.6301e-06 - reconstruction_loss: 0.0555 - val_adv_loss: 0.8440 - val_gen_loss: 0.4759 - val_kl_loss: 3.6377e-06 - val_reconstruction_loss: 0.0539
# Epoch 21/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 3.4039e-07 - gen_loss: 8.1143 - kl_loss: 1.3891e-05 - reconstruction_loss: 0.0552 - val_adv_loss: 0.8639 - val_gen_loss: 0.4855 - val_kl_loss: 2.5006e-06 - val_reconstruction_loss: 0.0536
# Epoch 22/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 0.0018 - gen_loss: 8.1143 - kl_loss: 5.4734e-06 - reconstruction_loss: 0.0553 - val_adv_loss: 5.1453 - val_gen_loss: 2.6255 - val_kl_loss: 1.9968e-06 - val_reconstruction_loss: 0.0529
# Epoch 23/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 3.4319e-07 - gen_loss: 8.1142 - kl_loss: 1.7550e-06 - reconstruction_loss: 0.0552 - val_adv_loss: 3.9638 - val_gen_loss: 2.0356 - val_kl_loss: 1.5059e-06 - val_reconstruction_loss: 0.0537
# Epoch 24/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 5.1161e-06 - gen_loss: 8.1142 - kl_loss: 1.2824e-06 - reconstruction_loss: 0.0551 - val_adv_loss: 2.5915 - val_gen_loss: 1.3486 - val_kl_loss: 1.0813e-06 - val_reconstruction_loss: 0.0528
# Epoch 25/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 2.7298e-07 - gen_loss: 8.1140 - kl_loss: 9.5953e-07 - reconstruction_loss: 0.0550 - val_adv_loss: 2.1714 - val_gen_loss: 1.1380 - val_kl_loss: 8.5775e-07 - val_reconstruction_loss: 0.0523
# Epoch 26/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 4.5726e-07 - gen_loss: 8.1138 - kl_loss: 7.6486e-07 - reconstruction_loss: 0.0548 - val_adv_loss: 1.3396 - val_gen_loss: 0.7225 - val_kl_loss: 6.7055e-07 - val_reconstruction_loss: 0.0527
# Epoch 27/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 2.5742e-07 - gen_loss: 8.1140 - kl_loss: 6.1240e-07 - reconstruction_loss: 0.0550 - val_adv_loss: 2.0763 - val_gen_loss: 1.0900 - val_kl_loss: 5.2154e-07 - val_reconstruction_loss: 0.0518
# Epoch 28/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 2.7028e-07 - gen_loss: 8.1139 - kl_loss: 4.9245e-07 - reconstruction_loss: 0.0549 - val_adv_loss: 1.1891 - val_gen_loss: 0.6476 - val_kl_loss: 4.7870e-07 - val_reconstruction_loss: 0.0531
# Epoch 29/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 4.5814e-07 - gen_loss: 8.1139 - kl_loss: 4.4522e-07 - reconstruction_loss: 0.0549 - val_adv_loss: 1.3829 - val_gen_loss: 0.7429 - val_kl_loss: 3.9022e-07 - val_reconstruction_loss: 0.0514
# Epoch 30/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 16.1181 - disc_loss: 2.4094e-07 - gen_loss: 8.1136 - kl_loss: 3.7428e-07 - reconstruction_loss: 0.0545 - val_adv_loss: 0.9819 - val_gen_loss: 0.5429 - val_kl_loss: 3.5856e-07 - val_reconstruction_loss: 0.0520
# Epoch 31/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 16.1181 - disc_loss: 2.5582e-07 - gen_loss: 8.1138 - kl_loss: 3.2463e-07 - reconstruction_loss: 0.0547 - val_adv_loss: 1.4697 - val_gen_loss: 0.7867 - val_kl_loss: 3.1013e-07 - val_reconstruction_loss: 0.0518
# Epoch 32/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 16.1181 - disc_loss: 2.4249e-07 - gen_loss: 8.1136 - kl_loss: 2.7540e-07 - reconstruction_loss: 0.0546 - val_adv_loss: 0.6720 - val_gen_loss: 0.3884 - val_kl_loss: 2.5705e-07 - val_reconstruction_loss: 0.0524
# Epoch 33/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 16.1181 - disc_loss: 2.5538e-07 - gen_loss: 8.1135 - kl_loss: 2.3917e-07 - reconstruction_loss: 0.0544 - val_adv_loss: 1.5095 - val_gen_loss: 0.8068 - val_kl_loss: 2.3283e-07 - val_reconstruction_loss: 0.0520
# Epoch 34/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 16.1181 - disc_loss: 5.3069e-07 - gen_loss: 8.1135 - kl_loss: 2.0617e-07 - reconstruction_loss: 0.0545 - val_adv_loss: 1.0850 - val_gen_loss: 0.5961 - val_kl_loss: 2.0117e-07 - val_reconstruction_loss: 0.0536
# Epoch 35/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 16.1181 - disc_loss: 2.6778e-07 - gen_loss: 8.1137 - kl_loss: 2.2457e-07 - reconstruction_loss: 0.0547 - val_adv_loss: 0.5358 - val_gen_loss: 0.3205 - val_kl_loss: 2.2911e-07 - val_reconstruction_loss: 0.0526
# Epoch 36/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - adv_loss: 16.1181 - disc_loss: 2.5689e-07 - gen_loss: 8.1135 - kl_loss: 2.4809e-07 - reconstruction_loss: 0.0544 - val_adv_loss: 0.7295 - val_gen_loss: 0.4166 - val_kl_loss: 2.1141e-07 - val_reconstruction_loss: 0.0518
# Epoch 37/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 2.8102e-07 - gen_loss: 8.1135 - kl_loss: 1.9885e-07 - reconstruction_loss: 0.0545 - val_adv_loss: 0.3424 - val_gen_loss: 0.2234 - val_kl_loss: 1.8626e-07 - val_reconstruction_loss: 0.0522
# Epoch 38/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 2.4282e-07 - gen_loss: 8.1134 - kl_loss: 1.9759e-07 - reconstruction_loss: 0.0544 - val_adv_loss: 0.7042 - val_gen_loss: 0.4048 - val_kl_loss: 1.9465e-07 - val_reconstruction_loss: 0.0527
# Epoch 39/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 2.4348e-07 - gen_loss: 8.1133 - kl_loss: 1.6712e-07 - reconstruction_loss: 0.0542 - val_adv_loss: 0.6532 - val_gen_loss: 0.3796 - val_kl_loss: 1.3597e-07 - val_reconstruction_loss: 0.0530
# Epoch 40/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - adv_loss: 16.1181 - disc_loss: 2.9618e-07 - gen_loss: 8.1134 - kl_loss: 1.4703e-07 - reconstruction_loss: 0.0543 - val_adv_loss: 0.5781 - val_gen_loss: 0.3418 - val_kl_loss: 1.5460e-07 - val_reconstruction_loss: 0.0528
# Epoch 41/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - adv_loss: 16.1181 - disc_loss: 4.3701e-06 - gen_loss: 8.1136 - kl_loss: 1.4637e-07 - reconstruction_loss: 0.0545 - val_adv_loss: 1.1176 - val_gen_loss: 0.6114 - val_kl_loss: 1.3970e-07 - val_reconstruction_loss: 0.0526
# Epoch 42/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - adv_loss: 16.1181 - disc_loss: 2.4199e-07 - gen_loss: 8.1133 - kl_loss: 1.3893e-07 - reconstruction_loss: 0.0543 - val_adv_loss: 2.7957 - val_gen_loss: 1.4502 - val_kl_loss: 1.3225e-07 - val_reconstruction_loss: 0.0523
# Epoch 43/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 2.4183e-07 - gen_loss: 8.1132 - kl_loss: 1.3593e-07 - reconstruction_loss: 0.0542 - val_adv_loss: 2.3941 - val_gen_loss: 1.2505 - val_kl_loss: 1.3504e-07 - val_reconstruction_loss: 0.0535
# Epoch 44/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 2.5461e-07 - gen_loss: 8.1133 - kl_loss: 1.4549e-07 - reconstruction_loss: 0.0543 - val_adv_loss: 1.1661 - val_gen_loss: 0.6346 - val_kl_loss: 1.4342e-07 - val_reconstruction_loss: 0.0516
# Epoch 45/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 2.3842e-07 - gen_loss: 8.1133 - kl_loss: 1.3489e-07 - reconstruction_loss: 0.0543 - val_adv_loss: 1.8397 - val_gen_loss: 0.9727 - val_kl_loss: 1.2666e-07 - val_reconstruction_loss: 0.0529
# Epoch 46/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - adv_loss: 16.1181 - disc_loss: 2.3868e-07 - gen_loss: 8.1134 - kl_loss: 1.3121e-07 - reconstruction_loss: 0.0543 - val_adv_loss: 1.3689 - val_gen_loss: 0.7361 - val_kl_loss: 1.3970e-07 - val_reconstruction_loss: 0.0517
# Epoch 47/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - adv_loss: 16.1181 - disc_loss: 2.3857e-07 - gen_loss: 8.1134 - kl_loss: 1.3111e-07 - reconstruction_loss: 0.0543 - val_adv_loss: 1.5241 - val_gen_loss: 0.8132 - val_kl_loss: 1.6578e-07 - val_reconstruction_loss: 0.0512
# Epoch 48/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - adv_loss: 16.1181 - disc_loss: 2.3848e-07 - gen_loss: 8.1132 - kl_loss: 1.3754e-07 - reconstruction_loss: 0.0541 - val_adv_loss: 1.0005 - val_gen_loss: 0.5513 - val_kl_loss: 1.2014e-07 - val_reconstruction_loss: 0.0510
# Epoch 49/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - adv_loss: 16.1181 - disc_loss: 2.3886e-07 - gen_loss: 8.1129 - kl_loss: 1.2590e-07 - reconstruction_loss: 0.0539 - val_adv_loss: 1.4633 - val_gen_loss: 0.7841 - val_kl_loss: 1.3132e-07 - val_reconstruction_loss: 0.0525
# Epoch 50/50
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - adv_loss: 16.1181 - disc_loss: 2.6071e-07 - gen_loss: 8.1131 - kl_loss: 1.4811e-07 - reconstruction_loss: 0.0540 - val_adv_loss: 0.7123 - val_gen_loss: 0.4076 - val_kl_loss: 1.4622e-07 - val_reconstruction_loss: 0.0514

# %%
# Validation evaluation:
val_anomalies = generate_synthetic_anomalies(X_val, noise_factor=2.0)
val_reconstructed = vae_gan.predict(X_val, batch_size=32)
val_loss_normal = compute_reconstruction_loss(X_val, val_reconstructed)
val_reconstructed_anom = vae_gan.predict(val_anomalies, batch_size=32)
val_loss_anom = compute_reconstruction_loss(val_anomalies, val_reconstructed_anom)
val_threshold = compute_threshold(val_loss_normal, k=1.5)
print(f"Validation adaptive threshold: {val_threshold:.4f}")
X_val_bal = np.concatenate([X_val, val_anomalies], axis=0)
y_val_true = np.concatenate([np.zeros(len(X_val)), np.ones(len(val_anomalies))])
val_reconstructed_bal = vae_gan.predict(X_val_bal, batch_size=32)
val_loss_bal = compute_reconstruction_loss(X_val_bal, val_reconstructed_bal)
y_val_pred = (val_loss_bal > val_threshold).astype(int)

val_accuracy = accuracy_score(y_val_true, y_val_pred)
val_precision = precision_score(y_val_true, y_val_pred, zero_division=1)
val_recall = recall_score(y_val_true, y_val_pred, zero_division=1)
val_f1 = f1_score(y_val_true, y_val_pred, zero_division=1)
val_cm = confusion_matrix(y_val_true, y_val_pred)
val_roc = roc_auc_score(y_val_true, val_loss_bal)
val_pr  = average_precision_score(y_val_true, val_loss_bal)

print("Validation Metrics:")
print(f"Accuracy: {val_accuracy:.4f}, Precision: {val_precision:.4f}, Recall: {val_recall:.4f}, F1: {val_f1:.4f}")
print(f"ROC-AUC: {val_roc:.4f}, PR-AUC: {val_pr:.4f}")
print("Confusion Matrix:")
print(val_cm)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 280ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step
# Validation adaptive threshold: 0.1045
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step
# Validation Metrics:
# Accuracy: 0.9591, Precision: 0.9243, Recall: 1.0000, F1: 0.9607
# ROC-AUC: 1.0000, PR-AUC: 1.0000
# Confusion Matrix:
# [[617  55]
#  [  0 672]]

# %%
# Test evaluation:
test_anomalies = generate_synthetic_anomalies(X_test, noise_factor=2.0)
test_reconstructed = vae_gan.predict(X_test, batch_size=32)
test_loss_normal = compute_reconstruction_loss(X_test, test_reconstructed)
test_reconstructed_anom = vae_gan.predict(test_anomalies, batch_size=32)
test_loss_anom = compute_reconstruction_loss(test_anomalies, test_reconstructed_anom)
test_threshold = val_threshold  # using the same threshold from validation
print(f"Test threshold (from validation): {test_threshold:.4f}")
X_test_bal = np.concatenate([X_test, test_anomalies], axis=0)
y_test_true = np.concatenate([np.zeros(len(X_test)), np.ones(len(test_anomalies))])
test_reconstructed_bal = vae_gan.predict(X_test_bal, batch_size=32)
test_loss_bal = compute_reconstruction_loss(X_test_bal, test_reconstructed_bal)
y_test_pred = (test_loss_bal > test_threshold).astype(int)

test_accuracy = accuracy_score(y_test_true, y_test_pred)
test_precision = precision_score(y_test_true, y_test_pred, zero_division=1)
test_recall = recall_score(y_test_true, y_test_pred, zero_division=1)
test_f1 = f1_score(y_test_true, y_test_pred, zero_division=1)
test_cm = confusion_matrix(y_test_true, y_test_pred)
test_roc = roc_auc_score(y_test_true, test_loss_bal)
test_pr  = average_precision_score(y_test_true, test_loss_bal)

print("Test Metrics:")
print(f"Accuracy: {test_accuracy:.4f}, Precision: {test_precision:.4f}, Recall: {test_recall:.4f}, F1: {test_f1:.4f}")
print(f"ROC-AUC: {test_roc:.4f}, PR-AUC: {test_pr:.4f}")
print("Confusion Matrix:")
print(test_cm)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step
# Test threshold (from validation): 0.1045
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 274ms/step
# Test Metrics:
# Accuracy: 0.9676, Precision: 0.9391, Recall: 1.0000, F1: 0.9686
# ROC-AUC: 1.0000, PR-AUC: 1.0000
# Confusion Matrix:
# [[245  17]
#  [  0 262]]

# %%
tf.saved_model.save(vae_gan, "saved_vae_gan")
# Out:
# INFO:tensorflow:Assets written to: saved_vae_gan/assets
# INFO:tensorflow:Assets written to: saved_vae_gan/assets
